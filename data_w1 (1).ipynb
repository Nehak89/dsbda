# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,LabelEncoder
import warnings 
warnings.simplefilter('ignore')

# %%
df=pd.read_csv(r"C:\data\dataset\iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
print(df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
print(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
print(f"Shape:{df.shape}")
# Out:
# Shape:(150, 6)

# %%
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
scaler=MinMaxScaler()
df_scaled=df.copy()

# %%
df_scaled[['SepalLengthCm','SepalWidthCm','PetalLengthCm',	'PetalWidthCm']]=scaler.fit_transform(
    df_scaled[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])
df_scaled
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1       0.222222      0.625000       0.067797      0.041667
# 1      2       0.166667      0.416667       0.067797      0.041667
# 2      3       0.111111      0.500000       0.050847      0.041667
# 3      4       0.083333      0.458333       0.084746      0.041667
# 4      5       0.194444      0.666667       0.067797      0.041667
# ..   ...            ...           ...            ...           ...
# 145  146       0.666667      0.416667       0.711864      0.916667
# 146  147       0.555556      0.208333       0.677966      0.750000
# 147  148       0.611111      0.416667       0.711864      0.791667
# 148  149       0.527778      0.583333       0.745763      0.916667
# 149  150       0.444444      0.416667       0.694915      0.708333
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
le=LabelEncoder()
df_label_encoded=df_scaled.copy()

# %%
df_label_encoded['Species']=le.fit_transform(df_label_encoded['Species'])
df_label_encoded
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1       0.222222      0.625000       0.067797      0.041667        0
# 1      2       0.166667      0.416667       0.067797      0.041667        0
# 2      3       0.111111      0.500000       0.050847      0.041667        0
# 3      4       0.083333      0.458333       0.084746      0.041667        0
# 4      5       0.194444      0.666667       0.067797      0.041667        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146       0.666667      0.416667       0.711864      0.916667        2
# 146  147       0.555556      0.208333       0.677966      0.750000        2
# 147  148       0.611111      0.416667       0.711864      0.791667        2
# 148  149       0.527778      0.583333       0.745763      0.916667        2
# 149  150       0.444444      0.416667       0.694915      0.708333        2
#
# [150 rows x 6 columns]

# %%
df_one_encoded=pd.get_dummies(df_scaled,columns=['Species'])
df_one_encoded
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1       0.222222      0.625000       0.067797      0.041667
# 1      2       0.166667      0.416667       0.067797      0.041667
# 2      3       0.111111      0.500000       0.050847      0.041667
# 3      4       0.083333      0.458333       0.084746      0.041667
# 4      5       0.194444      0.666667       0.067797      0.041667
# ..   ...            ...           ...            ...           ...
# 145  146       0.666667      0.416667       0.711864      0.916667
# 146  147       0.555556      0.208333       0.677966      0.750000
# 147  148       0.611111      0.416667       0.711864      0.791667
# 148  149       0.527778      0.583333       0.745763      0.916667
# 149  150       0.444444      0.416667       0.694915      0.708333
#
#      Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# 0                   True                    False                   False
# ...

# %%
sns.kdeplot(df['PetalLengthCm'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
plt.plot(df['Species'],df['SepalLengthCm'])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot example of Sepal Length by species')
plt.show()

# %%
plt.scatter(df['Species'],df['SepalLengthCm'])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot example of Sepal Length by species')
plt.show()
